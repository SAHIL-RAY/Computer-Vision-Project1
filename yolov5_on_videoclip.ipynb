# %% [markdown]
# <a href="https://colab.research.google.com/github/SAHIL-RAY/Computer-Vision-Project1/blob/main/yolov5_on_videoclip.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **SETUP**

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
import utils
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 13161, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (17/17), done.
# remote: Total 13161 (delta 8), reused 8 (delta 1), pack-reused 13143
# Receiving objects: 100% (13161/13161), 12.00 MiB | 29.12 MiB/s, done.
# Resolving deltas: 100% (9144/9144), done.
# /content/yolov5
#      |████████████████████████████████| 596 kB 28.0 MB/s

# %% [markdown]
# **Run Object Detection on Image**

# %%
# !python detect.py  --source /content/img.jpg --weights yolov5s.pt  --conf 0.4
# Out:
# detect: weights=['yolov5s.pt'], source=/content/img.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-172-ge305aba torch 1.11.0+cu113 CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# image 1/1 /content/img.jpg: 448x640 2 persons, 1 dog, 2 cell phones, Done. (0.372s)
# Speed: 6.5ms pre-process, 371.6ms inference, 2.0ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp12

# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
image=cv2.imread('/content/yolov5/runs/detect/exp12/img.jpg')
height, width=image.shape[:2]
resized_image=cv2.resize(image,(3*width, 3*height),interpolation=cv2.INTER_CUBIC)
fig=plt.gcf()
fig.set_size_inches(18,10)
plt.axis("off")
plt.imshow(cv2.cvtColor(resized_image,cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# **Detection On Video Clip**

# %%
# !python detect.py  --source /content/yolov5/data/video/pexels-george-morina-5274076.mp4 --weights yolov5s.pt  --conf 0.4
# Out:
# detect: weights=['yolov5s.pt'], source=/content/yolov5/data/video/pexels-george-morina-5274076.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-172-ge305aba torch 1.11.0+cu113 CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# video 1/1 (1/775) /content/yolov5/data/video/pexels-george-morina-5274076.mp4: 384x640 12 persons, 4 cars, 1 motorcycle, 3 trucks, 4 traffic lights, Done. (0.300s)
# video 1/1 (2/775) /content/yolov5/data/video/pexels-george-morina-5274076.mp4: 384x640 12 persons, 4 cars, 1 motorcycle, 3 trucks, 4 traffic lights, Done. (0.278s)
# ...
